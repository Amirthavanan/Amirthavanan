# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirthavanan/Amirthavanan/blob/main/AMIR1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=20
b=19
c=a-b
str (c)
print("THE VALUE OF A-B=",c)
# Out:
# THE VALUE OF A-B= 1

# %%
a="HI"
b=" AJ"
c=a+b
print("THE ADDITION=",c)
# Out:
# THE ADDITION= HI AJ

# %%
x=4.5
y=6.7
z=x+y
print(x)
print(y)
print(z)
# Out:
# 4.5
# 6.7
# 11.2

# %%
a=19
b="AJ"
(type(b))
# Out:
# str

# %%
x=6j
type(x)
# Out:
# complex

# %%
x=10<4
type(x)
x
# Out:
# False

# %%
x=input("ENTER NAME")
y="hi"
print(y+x)
# Out:
# ENTER NAMEamir
# hiamir

# %%
NAME="CRESCENT"
len(NAME)
# Out:
# 8

# %%
name="AMIR"
print(name[0:2])
# Out:
# AM

# %%
a=6
b=7
c=4
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**0.5
print("Area of triangle is",str(area))
# Out:
# Area of triangle is 11.976539567003485

# %%
a=6
y=5
