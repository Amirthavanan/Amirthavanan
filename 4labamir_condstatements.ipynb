# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirthavanan/Amirthavanan/blob/main/4labamir_condstatements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=eval(input("ENTER ANY NUMBER:"))
if num > 0:
  print(num,"is a +ve number.")
# Out:
# ENTER ANY NUMBER:9
# 9 is a +ve number.

# %%
num=eval(input("ENTER ANY NUMBER:"))
if num > 0:
  print(num,"is a +ve number.")
else:
  print(num,"is a -ve number.")
# Out:
# ENTER ANY NUMBER:-5
# -5 is a -ve number.

# %%
mark=eval(input("Enter your 12th mark out of 500:"))
if mark >=450 and mark <= 500:
  grade=print("....your grade is A....")
elif mark >= 400 and mark <= 450:
  grade=print("....your grade is B....")  
elif mark >= 350 and mark <= 400:
  grade=print("....your grade is C....")  
elif mark >= 300 and mark <= 350:
  grade=print("....your grade is D....")  
elif mark >= 250 and mark <= 300:
  grade=print("....your grade is E....")
else:
  print("...you are fail...")
# Out:
# Enter your 12th mark out of 500:249
# ...you are fail...

# %%
num=eval(input("Enter any number:"))
if (num != 0):
    if (num > 0):
      print("...Number is positive...")
    else:
      print("...Number is negative...")
else:
  print("...Number is Zero...")
# Out:
# Enter any number:55
# Number is positive
