# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirthavanan/Amirthavanan/blob/main/2NDLABAMIR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("CHOICE 1:ADDITION 2:SUBTRACTION 3:MUTIPLICATION 4:DIVISION 5:QUIT")
n1=input("ENTER YOUR CHOICE:")
n=int(n1)
if (n==1):
 a1 = input("ENTER NUMBER1:")
 b1 = input("ENTER NUMBER2:")
 a = int(a1)
 b = int(b1)
 c = a+b
 print("THE ADDITION OF",a,"+",b,"=",c)  
elif (n==2):
 a1 = input("ENTER THE NUMBER1:")
 b1 = input("ENTER THE NUMBER2:")
 a = int(a1)
 b = int(b1)
 c = a-b
 print("THE SUBTRACTION OF",a,"-",b,"=",c)
elif (n==3):
 a1 = input("ENTER THE NUMBER1:")
 b1 = input("ENTER THE NUMBER2:")
 a = int(a1)
 b = int(b1)
 c = a*b
 print("THE MULTIPLICATION OF",a,"*",b,"=",c)
elif (n==4):
 a1 = input("ENTER THE NUMBER1:")
 b1 = input("ENTER THE NUMBER2:")
 a = int(a1)
 b = int(b1)
 c = a/b
 print("THE DIVISION OF",a,"/",b,"=",c)
elif (n==5):
  exit()
# Out:
# CHOICE 1:ADDITION 2:SUBTRACTION 3:MUTIPLICATION 4:DIVISION 5:QUIT
# ENTER YOUR CHOICE:4
# ENTER THE NUMBER1:55
# ENTER THE NUMBER2:22
# THE DIVISION OF 55 / 22 = 2.5

# %%
N= int(input ("How many terms the user wants to print? "))  
N1 = 0  
N2 = 1  
count = 0  
if (N <= 0):  
    print ("Please enter a positive integer, the given number is not valid")    
elif (N == 1):  
    print ("The Fibonacci sequence of the numbers up to",N, ": ")  
    print(N1)  
else:  
    print ("The fibonacci sequence of the numbers is:")  
    while (count < N):  
        print(N1)  
        nth = N1 + N2  
        N1 = N2  
        N2 = nth  
        count += 1
# Out:
# How many terms the user wants to print? 5
# The fibonacci sequence of the numbers is:
# 0
# 1
# 1
# 2
# 3

# %%
num=int(input("Enter the number to find square root:"))
numsqrt = num**0.5
print("The square root of",num,"is",numsqrt)
# Out:
# enter the number to find square root:5
# the square root of 5 is 2.23606797749979

# %%
print("AREA OF 3ANGLE")
a=int(input("Enter a"))
b=int(input("Enter b"))
c=int(input("Enter c"))
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))/2
print("THE AREA OF THE TRIANGLE IS:",area)
# Out:
# AREA OF 3ANGLE
# Enter a4
# Enter b4
# Enter c4
# THE AREA OF THE TRIANGLE IS: 24.0

# %%
x=int(input("Enter the value 1:"))
y=int(input("Enter the value 2:"))
temp = x
x = y
y = temp
print("The value of x after swapping",x)
print("The value of y after swapping",y)
# Out:
# Enter the value 1:5
# Enter the value 2:7
# The value of x after swapping 7
# The value of y after swapping 5
